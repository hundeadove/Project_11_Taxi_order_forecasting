# %% [markdown]
# #  Прогнозирование заказов такси
#
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Построим модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# **Цель:**
# * Построить модель для предсказания количество заказов такси на следующий час.
#
#
# **Задачи:**
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
# ## Подготовка

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.model_selection import train_test_split, GridSearchCV, TimeSeriesSplit
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
import lightgbm as lgb

RANDOM_STATE=42

# %%
data = pd.read_csv(r'~/taxi.csv',  index_col='datetime', parse_dates=[0])
data.head(15)
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32
# 2018-03-01 00:50:00          21
# 2018-03-01 01:00:00           7
# 2018-03-01 01:10:00           5
# 2018-03-01 01:20:00          17
# 2018-03-01 01:30:00          12
# 2018-03-01 01:40:00          19
# 2018-03-01 01:50:00          25
# 2018-03-01 02:00:00          22
# 2018-03-01 02:10:00          12
# 2018-03-01 02:20:00          19

# %% [markdown]
# Проверим, в хронологическом ли порядке расположены даты и время.

# %%
data.index.is_monotonic
# Out:
# True

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %%
data.describe()
# Out:
#          num_orders
# count  26496.000000
# mean      14.070463
# std        9.211330
# min        0.000000
# 25%        8.000000
# 50%       13.000000
# 75%       19.000000
# max      119.000000

# %%
data.isna().sum()
# Out:
# num_orders    0
# dtype: int64

# %% [markdown]
# Данные чистые без пропусков.
#
# Выполним ресемплирование по одному часу. Так как предсказываем количество заказов такси на следующий час, аггрегируем суммы значений.

# %%
order = data.sort_index()
order = order.resample('1H').sum()
order.head()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00         124
# 2018-03-01 01:00:00          85
# 2018-03-01 02:00:00          71
# 2018-03-01 03:00:00          66
# 2018-03-01 04:00:00          43

# %%
print(f'Временный промежуток: от {order.index.min()} до {order.index.max()} ')
# Out:
# Временный промежуток: от 2018-03-01 00:00:00 до 2018-08-31 23:00:00

# %% [markdown]
# ## Анализ

# %% [markdown]
# Посмотрим на тренд и сезонность наших данных.

# %%
decomposed = seasonal_decompose(order)
decomposed_summer = seasonal_decompose(order['2018-06':'2018-08'])
decomposed_august = seasonal_decompose(order['2018-08-01':'2018-08-31'])

# %% [markdown]
# **Trend**

# %%
plt.style.use('ggplot')
plt.figure(figsize=(12, 8))
decomposed.trend.plot(ax=plt.gca())
plt.title('Trend')
plt.show()

# %%
decomposed.trend.rolling(25*7).mean().plot(ax=plt.gca(), color='red') 
decomposed.trend.plot(ax=plt.gca(), color='pink') 
plt.show()

# %% [markdown]
# Видно, что спрос повышается летом, пик в августе. Возможно, это связано с летними отпусками. Посмотрим поподробнее.

# %%
plt.figure(figsize=(12, 8))
decomposed_august.trend.plot(ax=plt.gca())
plt.title('trend in August')
plt.show()

# %% [markdown]
# Снова применить сглаживание.

# %%
decomposed_august.trend.rolling(50).mean().plot(ax=plt.gca(), color='red') 
decomposed_august.trend.plot(ax=plt.gca(), color='pink') 
plt.show()

# %% [markdown]
# * Спрос растет на всем промежутке времени.
# * Пик пока приходится на Август.

# %% [markdown]
# **Seasonal**

# %%
plt.figure(figsize=(12, 8))
decomposed_august.seasonal.plot(ax=plt.gca())
plt.title('Seasonal in Auguct')
plt.show()

# %% [markdown]
# По этому графику мало что можно сказать, рассмотрим конкретно день

# %%
decomposed_day = seasonal_decompose(order['2018-08-04':'2018-08-05'])
plt.figure(figsize=(12, 8))
decomposed_day.seasonal.plot(ax=plt.gca())
plt.title('Seasonal')
plt.show()

# %% [markdown]
# * Спрос на заказы начинает расти с утра, в 6 часов утра.
# * Пик приходися на 4-5 часа дня. К вечеру заказы активны.
# * После четырех часов утра заказы начинают падать.

# %% [markdown]
# **Resid**

# %%
plt.figure(figsize=(12, 8))
plt.title('Residuals')
decomposed.resid.plot(ax=plt.gca())
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.title('Residuals in August')
decomposed_august.resid.plot(ax=plt.gca())
plt.show()

# %% [markdown]
# * Величина кажется стабильной, за исключением всплесков. Возможно, это связано с выходными или праздниками.
#
# **Вывод:**
# * Тренд показывает, что спрос стремительно растет, пока пиком является Август.
# * Сезонность демонстрирует, что ночью спрос на заказы падает, растет в течении дня, пик приходится на 4-5 часов вечера.
# * Остаток декомпозиции также имеет постоянной среднее значение, но периодически возникают большие всплески (может объясняться повышенным спросом на такси по выходным и праздникам)

# %% [markdown]
# ## Обучение

# %% [markdown]
# Разделим датасет на тренировочную и тестовую выборки.

# %%
train, test = train_test_split(order, shuffle=False, test_size=0.1)

# %%
print("Среднее количество заказов в час:", test['num_orders'].mean())
# Out:
# Среднее количество заказов в час: 139.55656108597285

# %% [markdown]
# Проверим модель на адекватность двуми способами:
# * первый — прогнозом константой.
# * второй — предыдущим значением ряда.

# %%
pred_median = np.ones(test.shape) *  train['num_orders'].median()
print('RMSE:', mean_squared_error(test['num_orders'], pred_median) ** 0.5)
# Out:
# RMSE: 87.15277582981295

# %%
pred_previous = test['num_orders'].shift()
pred_previous.iloc[0] = train['num_orders'].iloc[-1]
print('RMSE:',  mean_squared_error(test['num_orders'], pred_previous)**0.5)
# Out:
# RMSE: 58.856486242815066

# %% [markdown]
# Ошибка во втором способе меньше.
#
# Напишем функцию для создания обучающих признаков таких как month, day, dayofweek и признаки для скользящего среднего rolling_mean и lag_i для признаков отстающего значения.

# %%
def make_features(data, max_lag, rolling_mean_size):
    data = data.copy()
    data['month'] = data.index.month
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)

    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()
    return data

# %%
df = make_features(order, 30, 50)

# %%
X = df.drop('num_orders', axis=1)
y = df['num_orders']

# %%
tscv = TimeSeriesSplit(n_splits=5)

for train_index, test_index in tscv.split(X):
    # Индексация DataFrame X и Series y по индексам train_index и test_index
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Шаг 1: Удаляем пустые значения из X_train
    X_train_cleaned = X_train.dropna()

    # Шаг 2: Фильтруем y_train, оставляя только те индексы (даты), которые есть в X_train_cleaned
    y_train_filtered = y_train[y_train.index.isin(X_train_cleaned.index)]

    # Шаг 3: Проверяем размеры X_train и y_train
    print(f"\nРазмер X_train: {X_train_cleaned.shape[0]}, размер y_train: {y_train_filtered.shape[0]}")

    # При необходимости: фильтрация X_train_cleaned для соответствия y_train_filtered
    X_filtered = X_train_cleaned[X_train_cleaned.index.isin(y_train_filtered.index)]

    # Шаг 4: Печатаем отфильтрованные данные
    print("\nОтфильтрованный X_train:")
    print(X_filtered)
    print("\nОтфильтрованный y_train:")
    print(y_train_filtered)
# Out:
# Размер X_train: 686, размер y_train: 686
#
# Отфильтрованный X_train:
#                      month  day  dayofweek  lag_1  lag_2  lag_3  lag_4  lag_5  \
# datetime
# 2018-03-03 02:00:00      3    3          5  108.0  163.0   72.0  119.0  101.0
# 2018-03-03 03:00:00      3    3          5   25.0  108.0  163.0   72.0  119.0
# 2018-03-03 04:00:00      3    3          5   64.0   25.0  108.0  163.0   72.0
# 2018-03-03 05:00:00      3    3          5   44.0   64.0   25.0  108.0  163.0
# 2018-03-03 06:00:00      3    3          5   15.0   44.0   64.0   25.0  108.0
# ...                    ...  ...        ...    ...    ...    ...    ...    ...
# 2018-03-31 11:00:00      3   31          5   48.0   65.0   56.0   20.0    7.0
# 2018-03-31 12:00:00      3   31          5   99.0   48.0   65.0   56.0   20.0
# 2018-03-31 13:00:00      3   31          5   24.0   99.0   48.0   65.0   56.0
# 2018-03-31 14:00:00      3   31          5   80.0   24.0   99.0   48.0   65.0
# ...

# %%
print(X_filtered.shape)
y_train_filtered.shape
# Out:
# (3630, 34)
# (3630,)

# %%
#здесь будем записывать результаты моделей
train_models = []

# %% [markdown]
# **GradientBoostingRegressor**

# %%
GBR = GradientBoostingRegressor()

# %%
parameters = {'learning_rate': [0.02, 0.03],
                  'subsample'    : [0.5, 0.6],
                  'n_estimators' : [100,200],
                  'max_depth'    : [5,6]
                 }

# %%
tscv = TimeSeriesSplit(n_splits=5)
grid_GBR = GridSearchCV(estimator=GBR, param_grid = parameters, cv =tscv,  scoring="neg_mean_squared_error", n_jobs=-1)
grid_GBR.fit(X_filtered, y_train_filtered)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#              estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.02, 0.03], 'max_depth': [5, 6],
#                          'n_estimators': [100, 200], 'subsample': [0.5, 0.6]},
#              scoring='neg_mean_squared_error')

# %%
print("\n The best estimator across ALL searched params:\n",grid_GBR.best_estimator_)
print("\n The best parameters across ALL searched params:\n",grid_GBR.best_params_)
# Out:
#  The best estimator across ALL searched params:
#  GradientBoostingRegressor(learning_rate=0.03, max_depth=6, n_estimators=200,
#                           subsample=0.5)
#
#  The best parameters across ALL searched params:
#  {'learning_rate': 0.03, 'max_depth': 6, 'n_estimators': 200, 'subsample': 0.5}

# %%
pred = grid_GBR.predict(X_filtered)
rmse_train = mean_squared_error(y_train_filtered, pred, squared=False)
print(rmse_train)
# Out:
# 13.108707874234328

# %%
train_models.append([GBR, rmse_train])

# %% [markdown]
# **RandomForestRegressor**

# %%
forest = RandomForestRegressor(random_state=RANDOM_STATE)

# %%
parameters = {'n_estimators':range(50,100,10), 
              'max_depth':range(1,11,2)}

tscv = TimeSeriesSplit(n_splits=2)

# %%
r_search = GridSearchCV(estimator=forest, cv=tscv, param_grid=parameters)

# %%
r_search.fit(X_filtered, y_train_filtered)
r_search.best_params_
# Out:
# {'max_depth': 9, 'n_estimators': 70}

# %%
predictions = r_search.predict(X_filtered)
rmse_train = mean_squared_error(y_train_filtered, predictions, squared=False)
rmse_train
# Out:
# 15.200786296506543

# %%
train_models.append([forest, rmse_train])

# %% [markdown]
# **DecisionTreeRegressor**

# %%
tree = DecisionTreeRegressor(random_state=RANDOM_STATE)
parameters = {'max_depth':range(1,11,2)}

tscv = TimeSeriesSplit(n_splits=2)
gsearch = GridSearchCV(estimator=tree, cv=tscv, param_grid=parameters)
gsearch.fit(X_filtered, y_train_filtered)
gsearch.best_params_
# Out:
# {'max_depth': 5}

# %%
predictions = gsearch.predict(X_filtered)
rmse_train = mean_squared_error(y_train_filtered, predictions, squared=False)
rmse_train
# Out:
# 24.040111384089098

# %%
train_models.append([tree, rmse_train])

# %% [markdown]
# **LightGBM**

# %%
lgbm = lgb.LGBMRegressor()

param_grid = {
    'num_leaves': [40, 51],
    'max_depth': [1, 10],
    'learning_rate': [0.01, 0.1]
    #'n_estimators': [100, 150]
}

tscv = TimeSeriesSplit(n_splits=2)

grid_search_lgbm = GridSearchCV(estimator=lgbm, 
                                param_grid=param_grid,
                                scoring="neg_mean_squared_error", 
                                cv=tscv,
                                verbose=False)


grid_search_lgbm.fit(X_filtered, y_train_filtered)


print("Лучшие параметры:", grid_search_lgbm.best_params_)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000414 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3983
# [LightGBM] [Info] Number of data points in the train set: 1210, number of used features: 34
# [LightGBM] [Info] Start training from score 58.615702
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
predictions = grid_search_lgbm.predict(X_filtered)
rmse_train = mean_squared_error(y_train_filtered, predictions, squared=False)
rmse_train
# Out:
# 9.659539529141664

# %%
train_models.append([lgbm, rmse_train])

# %% [markdown]
# Преобразуем массив в датафрейм результатов для удобства отображения и отсортируем по возрастанию RMSE.

# %%
result = pd.DataFrame(train_models, columns=['model', 'rmse_train'])

# %%
result.sort_values(by='rmse_train')
# Out:
#                                     model  rmse_train
# 3                         LGBMRegressor()    9.659540
# 0             GradientBoostingRegressor()   13.108708
# 1  RandomForestRegressor(random_state=42)   15.200786
# 2  DecisionTreeRegressor(random_state=42)   24.040111

# %% [markdown]
# У всех моделей оценка RMSE ниже 48.

# %% [markdown]
# ## Тестирование

# %% [markdown]
# Протестируем все модели и построим грфики.

# %%
test_models = []

# %%
#GradientBoostingRegressor
y_pred = grid_GBR.predict(X_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
test_models.append([GBR, rmse])

# %%
#RandomForestRegressor
y_pred = r_search.predict(X_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
test_models.append([forest, rmse_train])

# %%
#DecisionTreeRegressor
y_pred = gsearch.predict(X_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
test_models.append([tree, rmse_train])

# %%
#LightGBM
y_pred = grid_search_lgbm.predict(X_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
test_models.append([lgbm, rmse])

# %%
result = pd.DataFrame(test_models, columns=['model', 'rmse'])
result.sort_values(by='rmse')
# Out:
#                                     model       rmse
# 1  RandomForestRegressor(random_state=42)   9.659540
# 2  DecisionTreeRegressor(random_state=42)   9.659540
# 0             GradientBoostingRegressor()  40.917270
# 3                         LGBMRegressor()  42.795927

# %%
def pl(grid, title, rmse):
    preds = pd.Series(grid.predict(X_test), index = y_test.index, name='preds')
    df_preds = pd.concat([y_test, preds], axis=1)


    plt.figure(figsize=(14, 5))
    plt.style.use('ggplot')
    plt.title(title + ' (RMSE=' + str(rmse) + ')')
    data = df_preds['2018-08-20':]
    sns.lineplot(x=data.index, y=data['num_orders'], label='True Test')
    sns.lineplot(x=data.index, y=data['preds'], label='Predictions')

# %%
pl(r_search, 'RandomForestRegressor', round(result['rmse'][1], 2))

# %%
pl(gsearch, 'DecisionTreeRegressor', round(result['rmse'][2], 2))

# %%
pl(grid_search_lgbm, 'LGBMRegressor', round(result['rmse'][3], 2))

# %%
pl(grid_GBR, 'GradientBoostingRegressor', round(result['rmse'][0], 2))

# %% [markdown]
# **Итог:**
#
# * Отличились две модели с показателем RMSE 9.66: RandomForestRegressor и DecisionTreeRegressor.
# * Они хорошо предсказывают миниуммы и определяет ежедневно повторяющиеся тестовые данные. Однако редкие пики в данных предсказывают хуже.
